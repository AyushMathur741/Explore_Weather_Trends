# %%
import numpy as np
import pandas as pd

# %%
dataf = pd.read_csv(r"E:\Udacity_Projects\Explore_Weather_Trends\results.csv")
dataf.head()
# Out:
#    year  c_avg_temp  g_avg_temp
# 0  1796       24.49        8.27
# 1  1797       25.18        8.51
# 2  1798       24.65        8.67
# 3  1799       24.81        8.51
# 4  1800       24.85        8.48

# %%
dataf.info
# Out:
# <bound method DataFrame.info of      year  c_avg_temp  g_avg_temp
# 0    1796       24.49        8.27
# 1    1797       25.18        8.51
# 2    1798       24.65        8.67
# 3    1799       24.81        8.51
# 4    1800       24.85        8.48
# 5    1801       24.49        8.59
# 6    1802       25.44        8.58
# 7    1803       25.22        8.50
# 8    1804       25.67        8.84
# 9    1805       25.01        8.56
# 10   1806       24.87        8.43
# 11   1807       24.25        8.28
# 12   1808         NaN        7.63
# 13   1809         NaN        7.08
# 14   1810         NaN        6.92
# 15   1811         NaN        6.86
# 16   1812         NaN        7.05
# 17   1813       24.23        7.74
# 18   1814       23.91        7.59
# 19   1815       23.79        7.24
# 20   1816       23.30        6.94
# 21   1817       23.60        6.98
# 22   1818       23.94        7.83
# 23   1819       23.86        7.37
# 24   1820       23.91        7.62
# ...

# %%
dataf.isna().sum()
# Out:
# year          0
# c_avg_temp    7
# g_avg_temp    0
# dtype: int64

# %%
dataf1 = dataf.dropna(axis=0,inplace=False)
dataf1.reset_index(inplace=True)
del dataf1['index']
dataf1.head()
# Out:
#    year  c_avg_temp  g_avg_temp
# 0  1796       24.49        8.27
# 1  1797       25.18        8.51
# 2  1798       24.65        8.67
# 3  1799       24.81        8.51
# 4  1800       24.85        8.48

# %%
dataf1.tail()
# Out:
#      year  c_avg_temp  g_avg_temp
# 206  2009       25.73        9.51
# 207  2010       25.71        9.70
# 208  2011       25.36        9.52
# 209  2012       26.04        9.51
# 210  2013       26.61        9.61

# %%
dataf1.isna().sum()
# Out:
# year          0
# c_avg_temp    0
# g_avg_temp    0
# dtype: int64

# %%
df40 = dataf1[['c_avg_temp','g_avg_temp']].rolling(40,center=True).mean()
df40['year'] = dataf1['year']
df40
# Out:
#      c_avg_temp  g_avg_temp  year
# 0           NaN         NaN  1796
# 1           NaN         NaN  1797
# 2           NaN         NaN  1798
# 3           NaN         NaN  1799
# 4           NaN         NaN  1800
# 5           NaN         NaN  1801
# 6           NaN         NaN  1802
# 7           NaN         NaN  1803
# 8           NaN         NaN  1804
# 9           NaN         NaN  1805
# 10          NaN         NaN  1806
# 11          NaN         NaN  1807
# 12          NaN         NaN  1813
# 13          NaN         NaN  1814
# 14          NaN         NaN  1815
# 15          NaN         NaN  1816
# 16          NaN         NaN  1817
# 17          NaN         NaN  1818
# 18          NaN         NaN  1819
# 19          NaN         NaN  1820
# 20     24.46675     8.02325  1821
# 21     24.45575     8.00875  1822
# 22     24.43175     7.99650  1823
# 23     24.41525     7.98400  1824
# 24     24.40075     7.96250  1825
# 25     24.39100     7.94675  1826
# ...

# %%
df60.head()
# Out:
#    c_avg_temp  g_avg_temp  year
# 0         NaN         NaN  1796
# 1         NaN         NaN  1797
# 2         NaN         NaN  1798
# 3         NaN         NaN  1799
# 4         NaN         NaN  1800

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(22,30))
plt.subplot(326)
plt.plot(df60['year'],df60['c_avg_temp'],'y-')
plt.title('MA_60')
plt.xlabel('Years')
plt.ylabel('Average Teamperature')

plt.subplot(325)
plt.plot(df50['year'],df50['c_avg_temp'],'g-')
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('MA_50')

plt.subplot(324)
plt.plot(df40['year'],df40['c_avg_temp'],'m-')
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('MA_40')

plt.subplot(323)
plt.plot(df30['year'],df30['c_avg_temp'],'r-')
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('MA_30')
plt.subplot(322)
plt.plot(df15['year'],df15['c_avg_temp'],'b-')
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('MA_15')
plt.subplot(321)
plt.plot(dataf1['year'],dataf1['c_avg_temp'])
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('Original')

plt.rcParams.update({'font.size': 22})
plt.suptitle('City Temperature using Different MA Values')
plt.savefig(r"E:\Udacity_Projects\Explore_Weather_Trends\City_temp_ma.png")
plt.show()

# %%
plt.figure(figsize=(22,30))
plt.subplot(326)
plt.plot(df60['year'],df60['g_avg_temp'],'y-')
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('MA_60')

plt.subplot(325)
plt.plot(df50['year'],df50['g_avg_temp'],'g-')
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('MA_50')

plt.subplot(324)
plt.plot(df40['year'],df40['g_avg_temp'],'m-')
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('MA_40')

plt.subplot(323)
plt.plot(df30['year'],df30['g_avg_temp'],'r-')
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('MA_30')

plt.subplot(322)
plt.plot(df15['year'],df15['g_avg_temp'],'b-')
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('MA_15')

plt.subplot(321)
plt.plot(dataf1['year'],dataf1['g_avg_temp'])
plt.xlabel('Years')
plt.ylabel('Average Teamperature')
plt.title('Original')

plt.rcParams.update({'font.size': 22})
plt.suptitle('Global Temperature using Different MA Values')
plt.savefig(r"E:\Udacity_Projects\Explore_Weather_Trends\Global_temp_ma.png")
plt.show()

# %%
plt.figure(figsize=(22,10))
plt.subplot(121)
plt.plot(df40['year'],df40['c_avg_temp'],'r-',label='Bangalore')
plt.ylabel('Bengalore Temperature')
plt.xlabel('Years')
plt.title('MA_40')
plt.legend()
plt.subplot(122)
plt.plot(df40['year'],df40['g_avg_temp'],'m-',label='Global')
plt.ylabel('Global Temperature')
plt.xlabel('Years')
plt.title('MA_40')
plt.legend()
plt.suptitle('Bangalore Vs Global Temperature Trend')
plt.rcParams.update({'font.size': 16})
plt.savefig(r"E:\Udacity_Projects\Explore_Weather_Trends\Bangalore_vs_Global.png")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df40['year'],df40['c_avg_temp'],'r-',label='Bangalore')
plt.plot(df40['year'],df40['g_avg_temp'],'m-',label='Global')
plt.xlabel('Years')
plt.ylabel('Temperature')
plt.legend()
plt.suptitle('Bangalore Vs Global Temperature Trend')
plt.savefig(r"E:\Udacity_Projects\Explore_Weather_Trends\Bangalore_vs_Global_mix.png")
plt.show()

# %%
plt.figure(figsize=(12,6))

plt.plot(dataf1['year'],dataf1['c_avg_temp'],'r-')
plt.plot(dataf1['year'],dataf1['g_avg_temp'],'m-')
plt.title('Original')

plt.show()

# %%
plt.figure(figsize=(12,6))

c1=dataf1['c_avg_temp'][0]
g1=dataf1['g_avg_temp'][0]
plt.plot(dataf1['year'],dataf1['c_avg_temp']/c1,'r-')
plt.plot(dataf1['year'],dataf1['g_avg_temp']/g1,'m-')
plt.title('Original')

plt.show()

# %%
df40.iloc[18:22,]
# Out:
#     c_avg_temp  g_avg_temp  year
# 18         NaN         NaN  1819
# 19         NaN         NaN  1820
# 20    24.46675     8.02325  1821
# 21    24.45575     8.00875  1822

# %%
plt.figure(figsize=(22,10))
c1 = df40['c_avg_temp'][20]
g1 = df40['g_avg_temp'][20]
plt.plot(df40['year'],df40['c_avg_temp']/c1,'r-',label='City Temperature')
plt.plot(df40['year'],df40['g_avg_temp']/g1,'m-',label='Global Temperature')
plt.xlabel('Years')
plt.ylabel('Percentage Increase ')
plt.title('Bangalore Vs Global Temperature Trend')
plt.legend()
plt.grid()
plt.rcParams.update({'font.size': 19})
plt.savefig(r"E:\Udacity_Projects\Explore_Weather_Trends\Bangalore_vs_Global_final.png")
plt.show()

# %%
df40.iloc[190:192,]
# Out:
#      c_avg_temp  g_avg_temp  year
# 190    25.41500     9.12775  1993
# 191    25.44525     9.14425  1994

# %%
df40.iloc[53:110,]
# Out:
#      c_avg_temp  g_avg_temp  year
# 53     24.43250     8.00750  1854
# 54     24.43875     8.00575  1855
# 55     24.47225     8.03450  1856
# 56     24.49800     8.06275  1857
# 57     24.50450     8.08250  1858
# 58     24.51175     8.09775  1859
# 59     24.52475     8.11375  1860
# 60     24.52700     8.12200  1861
# 61     24.53200     8.12925  1862
# 62     24.53525     8.12300  1865
# 63     24.55100     8.11675  1866
# 64     24.55850     8.12425  1867
# 65     24.55475     8.12575  1868
# 66     24.54800     8.11425  1869
# 67     24.55750     8.12000  1870
# 68     24.56025     8.11975  1871
# 69     24.57600     8.12075  1872
# 70     24.58125     8.12500  1873
# 71     24.57950     8.12200  1874
# 72     24.58750     8.12350  1875
# 73     24.59025     8.12625  1876
# 74     24.60000     8.12625  1877
# 75     24.61375     8.13075  1878
# 76     24.63025     8.13525  1879
# 77     24.65200     8.15125  1880
# 78     24.67325     8.16125  1881
# ...

# %%
plt.figure(figsize=(22,10))
plt.subplot(121)
plt.plot(df40['year'],df40['c_avg_temp'].std(),'r-',label='Bangalore')
plt.ylabel('Bengalore Temperature')
plt.xlabel('Years')
plt.title('MA_40')
plt.legend()
plt.subplot(122)
plt.plot(df40['year'],df40['g_avg_temp'].std(),'m-',label='Global')
plt.ylabel('Global Temperature')
plt.xlabel('Years')
plt.title('MA_40')
plt.legend()
plt.suptitle('Bangalore Vs Global Temperature Trend')
plt.rcParams.update({'font.size': 16})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-d6fc3f25d325> in <module>()
#       1 plt.figure(figsize=(22,10))
#       2 plt.subplot(121)
# ----> 3 plt.plot(df40['year'],df40['c_avg_temp'].std(),'r-',label='Bangalore')
#       4 plt.ylabel('Bengalore Temperature')
#       5 plt.xlabel('Years')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
# ...

# %%
plt.plot(df50['year'],df50['c_avg_temp'],'g-')
plt.title('MA_50')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(15,6))
plt.plot(df50['year'],df50['c_avg_temp'],'g-',label='MA_50')
plt.plot(df30['year'],df30['c_avg_temp'],'r-',label='MA_30')
plt.plot(df15['year'],df15['c_avg_temp'],'b-',label='MA_15')
plt.legend()
plt.title('MA_30')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(df15['year'],df15['c_avg_temp'])
plt.title('MA_15')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(dataf1['year'],dataf1['c_avg_temp'])
plt.title('Original')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df['year'].head

# %%
dataf
# Out:
#      year  c_avg_temp  g_avg_temp
# 0    1796       24.49        8.27
# 1    1797       25.18        8.51
# 2    1798       24.65        8.67
# 3    1799       24.81        8.51
# 4    1800       24.85        8.48
# 5    1801       24.49        8.59
# 6    1802       25.44        8.58
# 7    1803       25.22        8.50
# 8    1804       25.67        8.84
# 9    1805       25.01        8.56
# 10   1806       24.87        8.43
# 11   1807       24.25        8.28
# 12   1808         NaN        7.63
# 13   1809         NaN        7.08
# 14   1810         NaN        6.92
# 15   1811         NaN        6.86
# 16   1812         NaN        7.05
# 17   1813       24.23        7.74
# 18   1814       23.91        7.59
# 19   1815       23.79        7.24
# 20   1816       23.30        6.94
# 21   1817       23.60        6.98
# 22   1818       23.94        7.83
# 23   1819       23.86        7.37
# 24   1820       23.91        7.62
# 25   1821       24.40        8.09
# ...

# %%
dataf.min()
# Out:
# year          1796.00
# c_avg_temp      23.30
# g_avg_temp       6.86
# dtype: float64

# %%
dataf.max()
# Out:
# year          2013.00
# c_avg_temp      26.61
# g_avg_temp       9.73
# dtype: float64

# %%
dataf1.mean()
# Out:
# year          1907.127962
# c_avg_temp      24.853081
# g_avg_temp       8.437630
# dtype: float64

# %%
dataf1[(dataf1['g_avg_temp']<=8.437630)]
# Out:
#      year  c_avg_temp  g_avg_temp
# 0    1796       24.49        8.27
# 10   1806       24.87        8.43
# 11   1807       24.25        8.28
# 12   1813       24.23        7.74
# 13   1814       23.91        7.59
# 14   1815       23.79        7.24
# 15   1816       23.30        6.94
# 16   1817       23.60        6.98
# 17   1818       23.94        7.83
# 18   1819       23.86        7.37
# 19   1820       23.91        7.62
# 20   1821       24.40        8.09
# 21   1822       24.33        8.19
# 22   1823       24.62        7.72
# 24   1825       24.69        8.39
# 25   1826       24.88        8.36
# 27   1828       24.61        8.17
# 28   1829       24.46        7.94
# 30   1831       24.43        7.64
# 31   1832       24.66        7.45
# 32   1833       24.46        8.01
# 33   1834       24.59        8.15
# 34   1835       23.89        7.39
# 35   1836       24.12        7.70
# 36   1837       24.13        7.38
# 37   1838       24.29        7.51
# ...

# %%
dataf1[(dataf1['c_avg_temp']<=24.853081)]
# Out:
#      year  c_avg_temp  g_avg_temp
# 0    1796       24.49        8.27
# 2    1798       24.65        8.67
# 3    1799       24.81        8.51
# 4    1800       24.85        8.48
# 5    1801       24.49        8.59
# 11   1807       24.25        8.28
# 12   1813       24.23        7.74
# 13   1814       23.91        7.59
# 14   1815       23.79        7.24
# 15   1816       23.30        6.94
# 16   1817       23.60        6.98
# 17   1818       23.94        7.83
# 18   1819       23.86        7.37
# 19   1820       23.91        7.62
# 20   1821       24.40        8.09
# 21   1822       24.33        8.19
# 22   1823       24.62        7.72
# 24   1825       24.69        8.39
# 26   1827       24.67        8.81
# 27   1828       24.61        8.17
# 28   1829       24.46        7.94
# 29   1830       24.39        8.52
# 30   1831       24.43        7.64
# 31   1832       24.66        7.45
# 32   1833       24.46        8.01
# 33   1834       24.59        8.15
# ...

# %%
dataf[dataf['c_avg_temp']==23.30]
# Out:
#     year  c_avg_temp  g_avg_temp
# 20  1816        23.3        6.94

# %%
dataf.max()
# Out:
# year          2013.00
# c_avg_temp      26.61
# g_avg_temp       9.73
# dtype: float64

# %%
dataf[dataf['c_avg_temp']==26.61]
# Out:
#      year  c_avg_temp  g_avg_temp
# 217  2013       26.61        9.61

# %%
dataf[dataf['g_avg_temp']==9.73]
# Out:
#      year  c_avg_temp  g_avg_temp
# 211  2007       25.46        9.73

# %%
dataf.min()
# Out:
# year          1796.00
# c_avg_temp      23.30
# g_avg_temp       6.86
# dtype: float64

# %%
dataf[dataf['c_avg_temp']==23.30]
# Out:
#     year  c_avg_temp  g_avg_temp
# 20  1816        23.3        6.94

# %%
dataf[dataf['g_avg_temp']==6.86]
# Out:
#     year  c_avg_temp  g_avg_temp
# 15  1811         NaN        6.86
